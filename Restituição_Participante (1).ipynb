# %%
from datetime import datetime, timedelta

def verificar_restituicao(data_ingresso, data_cancelamento):
    data_ingresso = datetime.strptime(data_ingresso, "%d/%m/%Y")
    data_cancelamento = datetime.strptime(data_cancelamento, "%d/%m/%Y")
    periodo_90_dias = data_ingresso + timedelta(days=90)

    if data_cancelamento <= periodo_90_dias:
        return "Sim"
    else:
        return "Não"

# Exemplo de uso
data_ingresso = "29/02/2024"
data_cancelamento = "02/05/2024"
direito_restituicao = verificar_restituicao(data_ingresso, data_cancelamento)
print(f"Direito à restituição integral: {direito_restituicao}")
# Out:
# Direito à restituição integral: Sim

# %%
# !pip install ipywidgets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 15.8 MB/s eta 0:00:00
# ...

# %%
from datetime import datetime, timedelta
import ipywidgets as widgets
from IPython.display import display

# %%
def verificar_restituicao(data_ingresso, data_cancelamento):
    data_ingresso = datetime.strptime(data_ingresso, "%d/%m/%Y")
    data_cancelamento = datetime.strptime(data_cancelamento, "%d/%m/%Y")
    periodo_90_dias = data_ingresso + timedelta(days=90)

    if data_cancelamento <= periodo_90_dias:
        return "Sim"
    else:
        return "Não"

# %%
# Widgets para entrada de dados
data_ingresso_widget = widgets.Text(
    description='Data de Ingresso:',
    placeholder='dd/mm/yyyy'
)

data_cancelamento_widget = widgets.Text(
    description='Data de Cancelamento:',
    placeholder='dd/mm/yyyy'
)

resultado_widget = widgets.Label(value='')

# Função para atualizar o resultado
def atualizar_resultado(b):
    data_ingresso = data_ingresso_widget.value
    data_cancelamento = data_cancelamento_widget.value
    try:
        resultado = verificar_restituicao(data_ingresso, data_cancelamento)
        resultado_widget.value = f"Direito à restituição integral: {resultado}"
    except ValueError:
        resultado_widget.value = "Por favor, insira datas válidas no formato dd/mm/yyyy."

# Botão para calcular
botao_calcular = widgets.Button(description='Calcular')
botao_calcular.on_click(atualizar_resultado)

# Exibir widgets
display(data_ingresso_widget, data_cancelamento_widget, botao_calcular, resultado_widget)
# Out:
# Text(value='', description='Data de Ingresso:', placeholder='dd/mm/yyyy')
# Text(value='', description='Data de Cancelamento:', placeholder='dd/mm/yyyy')
# Button(description='Calcular', style=ButtonStyle())
# Label(value='')

# %%
from datetime import datetime, timedelta
import ipywidgets as widgets
from IPython.display import display

def verificar_restituicao(data_ingresso, data_cancelamento):
    try:
        data_ingresso = datetime.strptime(data_ingresso, "%d/%m/%Y")
        data_cancelamento = datetime.strptime(data_cancelamento, "%d/%m/%Y")
    except ValueError:
        return "Formato de data inválido. Use dd/mm/yyyy."

    periodo_90_dias = data_ingresso + timedelta(days=90)

    if data_cancelamento <= periodo_90_dias:
        return "Sim"
    else:
        return "Não"

# Widgets para entrada de dados
data_ingresso_widget = widgets.Text(
    description='Data de Ingresso:',
    placeholder='dd/mm/yyyy'
)

data_cancelamento_widget = widgets.Text(
    description='Data de Cancelamento:',
    placeholder='dd/mm/yyyy'
)

resultado_widget = widgets.Label(value='')

# Função para atualizar o resultado
def atualizar_resultado(b):
    data_ingresso = data_ingresso_widget.value
    data_cancelamento = data_cancelamento_widget.value
    resultado = verificar_restituicao(data_ingresso, data_cancelamento)
    resultado_widget.value = f"Direito à restituição integral: {resultado}"

# Botão para calcular
botao_calcular = widgets.Button(description='Calcular')
botao_calcular.on_click(atualizar_resultado)

# Exibir widgets
display(data_ingresso_widget, data_cancelamento_widget, botao_calcular, resultado_widget)
# Out:
# Text(value='', description='Data de Ingresso:', placeholder='dd/mm/yyyy')
# Text(value='', description='Data de Cancelamento:', placeholder='dd/mm/yyyy')
# Button(description='Calcular', style=ButtonStyle())
# Label(value='')

# %%
from datetime import datetime, timedelta
import ipywidgets as widgets
from IPython.display import display

# %%
def verificar_restituicao(data_ingresso, data_cancelamento):
    periodo_90_dias = data_ingresso + timedelta(days=90)

    if data_cancelamento <= periodo_90_dias:
        return "Sim"
    else:
        return "Não"

# %%
# Widgets para entrada de dados
data_ingresso_widget = widgets.DatePicker(
    description='Data de Ingresso:',
    disabled=False
)

data_cancelamento_widget = widgets.DatePicker(
    description='Data de Cancelamento:',
    disabled=False
)

resultado_widget = widgets.Label(value='')

# Função para atualizar o resultado
def atualizar_resultado(b):
    data_ingresso = data_ingresso_widget.value
    data_cancelamento = data_cancelamento_widget.value

    if data_ingresso is None or data_cancelamento is None:
        resultado_widget.value = "Por favor, selecione ambas as datas."
    else:
        resultado = verificar_restituicao(data_ingresso, data_cancelamento)
        resultado_widget.value = f"Direito à restituição integral: {resultado}"

# Botão para calcular
botao_calcular = widgets.Button(description='Calcular')
botao_calcular.on_click(atualizar_resultado)

# Exibir widgets
display(data_ingresso_widget, data_cancelamento_widget, botao_calcular, resultado_widget)
# Out:
# DatePicker(value=None, description='Data de Ingresso:')
# DatePicker(value=None, description='Data de Cancelamento:')
# Button(description='Calcular', style=ButtonStyle())
# Label(value='')

# %%
from datetime import datetime, timedelta

def calcular_prazo(data_inicial, dias_corridos, feriados=[]):
    # Converter a data inicial para um objeto datetime
    data_inicial = datetime.strptime(data_inicial, "%d/%m/%Y")

    # Início da contagem no dia seguinte
    data_inicial += timedelta(days=1)

    # Contar os dias corridos
    data_final = data_inicial + timedelta(days=dias_corridos - 1)

    # Verificar se o último dia cai em um final de semana ou feriado
    while data_final.weekday() >= 5 or data_final.strftime("%d/%m/%Y") in feriados:
        data_final += timedelta(days=1)

    return data_final.strftime("%d/%m/%Y")

# Exemplo de uso
data_inicial = "29/02/2024"
dias_corridos = 90
feriados = ["01/05/2024", "25/12/2024"]  # Lista de feriados no formato dd/mm/yyyy

data_final = calcular_prazo(data_inicial, dias_corridos, feriados)
print(f"A data final do prazo é: {data_final}")
# Out:
# A data final do prazo é: 29/05/2024

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
from datetime import datetime, timedelta

def calcular_prazo(data_inicial, dias_corridos, feriados=[]):
    # Converter a data inicial para um objeto datetime
    data_inicial = datetime.strptime(data_inicial, "%d/%m/%Y")

    # Início da contagem no dia seguinte
    data_inicial += timedelta(days=1)

    # Contar os dias corridos
    data_final = data_inicial + timedelta(days=dias_corridos - 1)

    # Verificar se o último dia cai em um final de semana ou feriado
    while data_final.weekday() >= 5 or data_final.strftime("%d/%m/%Y") in feriados:
        data_final += timedelta(days=1)

    return data_final.strftime("%d/%m/%Y")

def calcular(b):
    clear_output()
    display(ui)

    data_inicial = data_inicial_widget.value
    dias_corridos = int(dias_corridos_widget.value)
    feriados = feriados_widget.value.split(",")
    feriados = [f.strip() for f in feriados if f.strip()]

    try:
        data_final = calcular_prazo(data_inicial, dias_corridos, feriados)
        print(f"A data final do prazo é: {data_final}")
    except Exception as e:
        print(f"Ocorreu um erro: {e}")

# Widgets de entrada
data_inicial_widget = widgets.Text(
    description='Data Inicial:',
    placeholder='dd/mm/yyyy'
)

dias_corridos_widget = widgets.Text(
    description='Dias Corridos:',
    placeholder='Número de dias'
)

feriados_widget = widgets.Text(
    description='Feriados:',
    placeholder='dd/mm/yyyy, separados por vírgula'
)

# Botão para calcular
calcular_button = widgets.Button(
    description='Calcular',
    button_style='success'
)

calcular_button.on_click(calcular)

# Interface de usuário
ui = widgets.VBox([
    data_inicial_widget,
    dias_corridos_widget,
    feriados_widget,
    calcular_button
])

display(ui)

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
from datetime import datetime, timedelta

# Lista de feriados (exemplo)
feriados = ["01/01/2024", "25/12/2024", "01/05/2024"]  # Adicione os feriados relevantes aqui

def calcular_prazo(data_inicial, dias_corridos, feriados=[]):
    # Converter a data inicial para um objeto datetime
    data_inicial = datetime.strptime(data_inicial, "%d/%m/%Y")

    # Contar os dias corridos
    data_final = data_inicial + timedelta(days=dias_corridos)

    # Verificar se o último dia cai em um final de semana ou feriado
    while data_final.weekday() >= 5 or data_final.strftime("%d/%m/%Y") in feriados:
        data_final += timedelta(days=1)

    return data_final.strftime("%d/%m/%Y")

def calcular(b):
    clear_output()
    display(ui)

    data_inicial = data_inicial_widget.value
    dias_corridos = int(dias_corridos_widget.value)

    try:
        data_final = calcular_prazo(data_inicial, dias_corridos, feriados)

        # Verificar se o cancelamento foi solicitado dentro de 90 dias
        data_inicial_dt = datetime.strptime(data_inicial, "%d/%m/%Y")
        data_final_dt = datetime.strptime(data_final, "%d/%m/%Y")
        delta_dias = (data_final_dt - data_inicial_dt).days

        if delta_dias <= 90:
            direito_restituicao = "Sim"
        else:
            direito_restituicao = "Não"

        print(f"A data final do prazo é: {data_final}")
        print(f"Direito à restituição integral: {direito_restituicao}")
    except Exception as e:
        print(f"Ocorreu um erro: {e}")

# Widgets de entrada
data_inicial_widget = widgets.Text(
    description='Data Inicial:',
    placeholder='dd/mm/yyyy'
)

dias_corridos_widget = widgets.Text(
    description='Dias Corridos:',
    placeholder='Número de dias'
)

# Botão para calcular
calcular_button = widgets.Button(
    description='Calcular',
    button_style='success'
)

calcular_button.on_click(calcular)

# Interface de usuário
ui = widgets.VBox([
    data_inicial_widget,
    dias_corridos_widget,
    calcular_button
])

display(ui)

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
from datetime import datetime, timedelta

# Lista de feriados (exemplo)
feriados = ["01/01/2024", "25/12/2024", "01/05/2024"]  # Adicione os feriados relevantes aqui

def calcular_prazo(data_inicial, dias_corridos, feriados=[]):
    # Converter a data inicial para um objeto datetime
    data_inicial = datetime.strptime(data_inicial, "%d/%m/%Y")

    # Contar os dias corridos
    data_final = data_inicial + timedelta(days=dias_corridos)

    # Verificar se o último dia cai em um final de semana ou feriado
    while data_final.weekday() >= 5 or data_final.strftime("%d/%m/%Y") in feriados:
        data_final += timedelta(days=1)

    return data_final.strftime("%d/%m/%Y")

def calcular(b):
    clear_output()
    display(ui)

    data_inicial = data_inicial_widget.value
    dias_corridos = int(dias_corridos_widget.value)

    try:
        data_final = calcular_prazo(data_inicial, dias_corridos, feriados)

        # Verificar se o cancelamento foi solicitado dentro de 90 dias
        data_inicial_dt = datetime.strptime(data_inicial, "%d/%m/%Y")
        data_final_dt = datetime.strptime(data_final, "%d/%m/%Y")
        delta_dias = (data_final_dt - data_inicial_dt).days

        if delta_dias <= 90:
            direito_restituicao = "Sim"
        else:
            direito_restituicao = "Não"

        print(f"A data final do prazo é: {data_final}")
        print(f"Direito à restituição integral: {direito_restituicao}")
    except Exception as e:
        print(f"Ocorreu um erro: {e}")

# Widgets de entrada
data_inicial_widget = widgets.Text(
    description='Data Inicial:',
    placeholder='dd/mm/yyyy'
)

dias_corridos_widget = widgets.Text(
    description='Dias Corridos:',
    placeholder='Número de dias'
)

# Botão para calcular
calcular_button = widgets.Button(
    description='Calcular',
    button_style='success'
)

calcular_button.on_click(calcular)

# Interface de usuário
ui = widgets.VBox([
    data_inicial_widget,
    dias_corridos_widget,
    calcular_button
])

display(ui)
# Out:
# ...
# A data final do prazo é: 11/07/2023
# Direito à restituição integral: Sim

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
from datetime import datetime, timedelta

# Lista de feriados (exemplo)
feriados = ["01/01/2024", "25/12/2024", "01/05/2024"]  # Adicione os feriados relevantes aqui

def calcular_prazo(data_inicial, dias_corridos, feriados=[]):
    # Converter a data inicial para um objeto datetime
    data_inicial = datetime.strptime(data_inicial, "%d/%m/%Y")

    # Contar os dias corridos
    data_final = data_inicial + timedelta(days=dias_corridos)

    # Verificar se o último dia cai em um final de semana ou feriado
    while data_final.weekday() >= 5 or data_final.strftime("%d/%m/%Y") in feriados:
        data_final += timedelta(days=1)

    return data_final.strftime("%d/%m/%Y")

def calcular(b):
    clear_output()
    display(ui)

    data_inicial = data_inicial_widget.value
    data_termino = data_termino_widget.value

    try:
        data_inicial_dt = datetime.strptime(data_inicial, "%d/%m/%Y")
        data_termino_dt = datetime.strptime(data_termino, "%d/%m/%Y")

        # Calcular dias corridos
        dias_corridos = (data_termino_dt - data_inicial_dt).days

        # Verificar se o cancelamento foi solicitado dentro de 90 dias
        if dias_corridos <= 90:
            direito_restituicao = "Sim"
        else:
            direito_restituicao = "Não"

        print(f"Dias corridos: {dias_corridos}")
        print(f"Direito à restituição integral: {direito_restituicao}")
    except Exception as e:
        print(f"Ocorreu um erro: {e}")

# Widgets de entrada
data_inicial_widget = widgets.Text(
    description='Data Inicial:',
    placeholder='dd/mm/yyyy'
)

data_termino_widget = widgets.Text(
    description='Data de Término:',
    placeholder='dd/mm/yyyy'
)

# Botão para calcular
calcular_button = widgets.Button(
    description='Calcular',
    button_style='success'
)

calcular_button.on_click(calcular)

# Interface de usuário
ui = widgets.VBox([
    data_inicial_widget,
    data_termino_widget,
    calcular_button
])

display(ui)

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
from datetime import datetime, timedelta

# Lista de feriados (exemplo)
feriados = ["01/01/2024", "25/12/2024", "01/05/2024"]  # Adicione os feriados relevantes aqui

def calcular(b):
    clear_output()
    display(ui)

    data_inicial = data_inicial_widget.value
    data_termino = data_termino_widget.value

    try:
        # Validar e converter as datas para o formato datetime
        data_inicial_dt = datetime.strptime(data_inicial, "%d/%m/%Y")
        data_termino_dt = datetime.strptime(data_termino, "%d/%m/%Y")

        # Calcular dias corridos
        dias_corridos = (data_termino_dt - data_inicial_dt).days

        # Verificar se o cancelamento foi solicitado dentro de 90 dias
        if dias_corridos <= 90:
            direito_restituicao = "Sim"
        else:
            direito_restituicao = "Não"

        print(f"Dias corridos: {dias_corridos}")
        print(f"Direito à restituição integral: {direito_restituicao}")
    except ValueError:
        print("Por favor, insira as datas no formato dd/mm/yyyy.")
    except Exception as e:
        print(f"Ocorreu um erro: {e}")

# Widgets de entrada
data_inicial_widget = widgets.Text(
    description='Data Inicial:',
    placeholder='dd/mm/yyyy'
)

data_termino_widget = widgets.Text(
    description='Data de Término:',
    placeholder='dd/mm/yyyy'
)

# Botão para calcular
calcular_button = widgets.Button(
    description='Calcular',
    button_style='success'
)

calcular_button.on_click(calcular)

# Interface de usuário
ui = widgets.VBox([
    data_inicial_widget,
    data_termino_widget,
    calcular_button
])

display(ui)

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
from datetime import datetime, timedelta

# Lista de feriados (exemplo)
feriados = ["01/01/2024", "25/12/2024", "01/05/2024"]  # Adicione os feriados relevantes aqui

def formatar_data(data):
    """Formata a data para o formato dd/mm/yyyy enquanto o usuário digita."""
    data = data.replace("/", "")
    if len(data) > 2:
        data = data[:2] + '/' + data[2:]
    if len(data) > 5:
        data = data[:5] + '/' + data[5:]
    return data

def on_data_inicial_change(change):
    """Callback para formatar a data inicial."""
    with data_inicial_widget.hold_trait_notifications():
        data_inicial_widget.value = formatar_data(change['new'])

def on_data_termino_change(change):
    """Callback para formatar a data de término."""
    with data_termino_widget.hold_trait_notifications():
        data_termino_widget.value = formatar_data(change['new'])

def calcular(b):
    clear_output()
    display(ui)

    data_inicial = data_inicial_widget.value
    data_termino = data_termino_widget.value

    try:
        # Validar e converter as datas para o formato datetime
        data_inicial_dt = datetime.strptime(data_inicial, "%d/%m/%Y")
        data_termino_dt = datetime.strptime(data_termino, "%d/%m/%Y")

        # Calcular dias corridos
        dias_corridos = (data_termino_dt - data_inicial_dt).days

        # Verificar se o cancelamento foi solicitado dentro de 90 dias
        if dias_corridos <= 90:
            direito_restituicao = "Sim"
        else:
            direito_restituicao = "Não"

        print(f"Dias corridos: {dias_corridos}")
        print(f"Direito à restituição integral: {direito_restituicao}")
    except ValueError:
        print("Por favor, insira as datas no formato dd/mm/yyyy.")
    except Exception as e:
        print(f"Ocorreu um erro: {e}")

# Widgets de entrada
data_inicial_widget = widgets.Text(
    description='Data Inicial:',
    placeholder='dd/mm/yyyy'
)
data_inicial_widget.observe(on_data_inicial_change, names='value')

data_termino_widget = widgets.Text(
    description='Data de Término:',
    placeholder='dd/mm/yyyy'
)
data_termino_widget.observe(on_data_termino_change, names='value')

# Botão para calcular
calcular_button = widgets.Button(
    description='Calcular',
    button_style='success'
)

calcular_button.on_click(calcular)

# Interface de usuário
ui = widgets.VBox([
    data_inicial_widget,
    data_termino_widget,
    calcular_button
])

display(ui)
# Out:
# ...
# Dias corridos: 98
# Direito à restituição integral: Não

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
from datetime import datetime, timedelta

# Lista de feriados (exemplo)
feriados = ["01/01/2024", "25/12/2024", "01/05/2024"]  # Adicione os feriados relevantes aqui

def formatar_data(data):
    """Formata a data para o formato dd/mm/yyyy enquanto o usuário digita."""
    data = data.replace("/", "")
    if len(data) > 2:
        data = data[:2] + '/' + data[2:]
    if len(data) > 5:
        data = data[:5] + '/' + data[5:]
    return data

def on_data_inicial_change(change):
    """Callback para formatar a data inicial."""
    with data_inicial_widget.hold_trait_notifications():
        data_inicial_widget.value = formatar_data(change['new'])

def on_data_termino_change(change):
    """Callback para formatar a data de término."""
    with data_termino_widget.hold_trait_notifications():
        data_termino_widget.value = formatar_data(change['new'])

def calcular(b):
    clear_output()
    display(ui)

    data_inicial = data_inicial_widget.value
    data_termino = data_termino_widget.value

    try:
        # Validar e converter as datas para o formato datetime
        data_inicial_dt = datetime.strptime(data_inicial, "%d/%m/%Y")
        data_termino_dt = datetime.strptime(data_termino, "%d/%m/%Y")

        # Calcular dias corridos
        dias_corridos = (data_termino_dt - data_inicial_dt).days

        # Verificar se o cancelamento foi solicitado dentro de 90 dias
        if dias_corridos <= 90:
            direito_restituicao = "Sim"
        else:
            direito_restituicao = "Não"

        print(f"Dias corridos: {dias_corridos}")
        print(f"Direito à restituição integral: {direito_restituicao}")
    except ValueError:
        print("Por favor, insira as datas no formato dd/mm/yyyy.")
    except Exception as e:
        print(f"Ocorreu um erro: {e}")

# Widgets de entrada
data_inicial_widget = widgets.Text(
    description='Data Inicial:',
    placeholder='dd/mm/yyyy'
)
data_inicial_widget.observe(on_data_inicial_change, names='value')

data_termino_widget = widgets.Text(
    description='Data de Término:',
    placeholder='dd/mm/yyyy'
)
data_termino_widget.observe(on_data_termino_change, names='value')

# Botão para calcular
calcular_button = widgets.Button(
    description='Calcular',
    button_style='success'
)

calcular_button.on_click(calcular)

# Interface de usuário
ui = widgets.VBox([
    data_inicial_widget,
    data_termino_widget,
    calcular_button
])

display(ui)

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
from datetime import datetime, timedelta

# Lista de feriados (exemplo)
feriados = ["01/01/2024", "25/12/2024", "01/05/2024"]  # Adicione os feriados relevantes aqui

def formatar_data(data):
    """Formata a data para o formato dd/mm/yyyy enquanto o usuário digita."""
    data = data.replace("/", "")
    if len(data) > 2:
        data = data[:2] + '/' + data[2:]
    if len(data) > 5:
        data = data[:5] + '/' + data[5:]
    return data

def on_data_inicial_change(change):
    """Callback para formatar a data inicial."""
    with data_inicial_widget.hold_trait_notifications():
        data_inicial_widget.value = formatar_data(change['new'])

def on_data_termino_change(change):
    """Callback para formatar a data de término."""
    with data_termino_widget.hold_trait_notifications():
        data_termino_widget.value = formatar_data(change['new'])

def is_dia_util(data):
    """Verifica se a data é um dia útil (não é fim de semana nem feriado)."""
    if data.weekday() >= 5 or data.strftime("%d/%m/%Y") in feriados:
        return False
    return True

def calcular(b):
    clear_output()
    display(ui)

    data_inicial = data_inicial_widget.value
    data_termino = data_termino_widget.value

    try:
        # Validar e converter as datas para o formato datetime
        data_inicial_dt = datetime.strptime(data_inicial, "%d/%m/%Y")
        data_termino_dt = datetime.strptime(data_termino, "%d/%m/%Y")

        # Calcular dias corridos
        dias_corridos = (data_termino_dt - data_inicial_dt).days

        # Verificar se o cancelamento foi solicitado dentro de 90 dias
        if dias_corridos <= 90:
            direito_restituicao = "Sim"
        else:
            direito_restituicao = "Não"

        # Verificar se a data de término é um dia útil
        if is_dia_util(data_termino_dt):
            print(f"A data final {data_termino_dt.strftime('%d/%m/%Y')} é um dia útil.")
        else:
            # Prorrogar data de término se cair em dia não útil
            data_final_prorrogada = data_termino_dt
            while not is_dia_util(data_final_prorrogada):
                data_final_prorrogada += timedelta(days=1)
            print(f"A data final {data_termino_dt.strftime('%d/%m/%Y')} não é um dia útil.")
            print(f"A data final foi prorrogada para {data_final_prorrogada.strftime('%d/%m/%Y')} por cair em dia não útil.")

        print(f"Dias corridos: {dias_corridos}")
        print(f"Direito à restituição integral: {direito_restituicao}")
    except ValueError:
        print("Por favor, insira as datas no formato dd/mm/yyyy.")
    except Exception as e:
        print(f"Ocorreu um erro: {e}")

# Widgets de entrada
data_inicial_widget = widgets.Text(
    description='Data Inicial:',
    placeholder='dd/mm/yyyy'
)
data_inicial_widget.observe(on_data_inicial_change, names='value')

data_termino_widget = widgets.Text(
    description='Data de Término:',
    placeholder='dd/mm/yyyy'
)
data_termino_widget.observe(on_data_termino_change, names='value')

# Botão para calcular
calcular_button = widgets.Button(
    description='Calcular',
    button_style='success'
)

calcular_button.on_click(calcular)

# Interface de usuário
ui = widgets.VBox([
    data_inicial_widget,
    data_termino_widget,
    calcular_button
])

display(ui)

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
from datetime import datetime, timedelta

# Lista de feriados (exemplo)
feriados = ["01/01/2024", "25/12/2024", "01/05/2024"]  # Adicione os feriados relevantes aqui

def formatar_data(data):
    """Formata a data para o formato dd/mm/yyyy enquanto o usuário digita."""
    data = data.replace("/", "")
    if len(data) > 2:
        data = data[:2] + '/' + data[2:]
    if len(data) > 5:
        data = data[:5] + '/' + data[5:]
    return data

def on_data_inicial_change(change):
    """Callback para formatar a data inicial."""
    with data_inicial_widget.hold_trait_notifications():
        data_inicial_widget.value = formatar_data(change['new'])

def on_data_termino_change(change):
    """Callback para formatar a data de término."""
    with data_termino_widget.hold_trait_notifications():
        data_termino_widget.value = formatar_data(change['new'])

def is_dia_util(data):
    """Verifica se a data é um dia útil (não é fim de semana nem feriado)."""
    if data.weekday() >= 5 or data.strftime("%d/%m/%Y") in feriados:
        return False
    return True

def calcular(b):
    clear_output()
    display(ui)

    data_inicial = data_inicial_widget.value
    data_termino = data_termino_widget.value

    try:
        # Validar e converter as datas para o formato datetime
        data_inicial_dt = datetime.strptime(data_inicial, "%d/%m/%Y")
        data_termino_dt = datetime.strptime(data_termino, "%d/%m/%Y")

        # Calcular dias corridos
        dias_corridos = (data_termino_dt - data_inicial_dt).days

        # Verificar se o cancelamento foi solicitado dentro de 90 dias
        if dias_corridos <= 90:
            direito_restituicao = "Sim"
        else:
            direito_restituicao = "Não"

        # Verificar se a data de término é um dia útil
        if is_dia_util(data_termino_dt):
            print(f"A data final {data_termino_dt.strftime('%d/%m/%Y')} é um dia útil.")
            print(f"Dia útil do mês: {data_termino_dt.day}")
        else:
            # Prorrogar data de término se cair em dia não útil
            data_final_prorrogada = data_termino_dt
            while not is_dia_util(data_final_prorrogada):
                data_final_prorrogada += timedelta(days=1)
            print(f"A data final {data_termino_dt.strftime('%d/%m/%Y')} não é um dia útil.")
            print(f"A data final foi prorrogada para {data_final_prorrogada.strftime('%d/%m/%Y')} por cair em dia não útil.")
            print(f"Dia útil do mês: {data_final_prorrogada.day}")

        print(f"Dias corridos: {dias_corridos}")
        print(f"Direito à restituição integral: {direito_restituicao}")
    except ValueError:
        print("Por favor, insira as datas no formato dd/mm/yyyy.")
    except Exception as e:
        print(f"Ocorreu um erro: {e}")

# Widgets de entrada
data_inicial_widget = widgets.Text(
    description='Data Inicial:',
    placeholder='dd/mm/yyyy'
)
data_inicial_widget.observe(on_data_inicial_change, names='value')

data_termino_widget = widgets.Text(
    description='Data de Término:',
    placeholder='dd/mm/yyyy'
)
data_termino_widget.observe(on_data_termino_change, names='value')

# Botão para calcular
calcular_button = widgets.Button(
    description='Calcular',
    button_style='success'
)

calcular_button.on_click(calcular)

# Interface de usuário
ui = widgets.VBox([
    data_inicial_widget,
    data_termino_widget,
    calcular_button
])

display(ui)

# %%
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.3/383.3 kB 19.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.24.0
#     Uninstalling jupyter-server-1.24.0:
#       Successfully uninstalled jupyter-server-1.24.0
# ...
